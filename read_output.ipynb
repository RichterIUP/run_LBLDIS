# %%
import scipy.io as io
import matplotlib.pyplot as plt

# %%
with io.netcdf_file("out/lbldisout.cdf", "r") as file_:
    print(file_.variables)
    wnum = file_.variables['wnum'][:].copy()
    radiance = file_.variables['radiance'][:].copy()
# Out:
# OrderedDict([('wnum', <scipy.io.netcdf.netcdf_variable object at 0x7fe33ca36f10>), ('radiance', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600090>), ('flux_up', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600250>), ('flux_down', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c6003d0>), ('flux_beam', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600650>), ('cld_height', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600550>), ('cld_dbnum', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600790>), ('cld_tau', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600910>), ('cld_tau_wnum', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600a90>), ('cld_reff', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600c10>), ('sfc_temperature', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c600d90>), ('sfc_emissivity', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c604150>), ('pwv', <scipy.io.netcdf.netcdf_variable object at 0x7fe33c604110>), ('height', <
# ...

# %%
plt.plot(wnum, radiance)
