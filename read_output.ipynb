# %%
import scipy.io as io
import matplotlib.pyplot as plt
import shutil

# %% [raw]
# shutil.copyfile("out/lbldisout.cdf", "out/tau_0.cdf")

# %%
radiance = [None, None, None, None, None, None, None]
with io.netcdf_file("out/tau_10.cdf", "r") as file_:
    wnum = file_.variables['wnum'][:].copy()
    radiance_cdf = file_.variables['radiance'][:].copy()
radiance[0] = radiance_cdf[(wnum > 400) & (wnum < 1900)]
wnum = wnum[(wnum > 400) & (wnum < 1900)]

with io.netcdf_file("out/tau_08.cdf", "r") as file_:
    wnum = file_.variables['wnum'][:].copy()
    radiance_cdf = file_.variables['radiance'][:].copy()
radiance[1] = radiance_cdf[(wnum > 400) & (wnum < 1900)]
wnum = wnum[(wnum > 400) & (wnum < 1900)]

with io.netcdf_file("out/tau_06.cdf", "r") as file_:
    wnum = file_.variables['wnum'][:].copy()
    radiance_cdf = file_.variables['radiance'][:].copy()
radiance[2] = radiance_cdf[(wnum > 400) & (wnum < 1900)]
wnum = wnum[(wnum > 400) & (wnum < 1900)]

with io.netcdf_file("out/tau_04.cdf", "r") as file_:
    wnum = file_.variables['wnum'][:].copy()
    radiance_cdf = file_.variables['radiance'][:].copy()
radiance[3] = radiance_cdf[(wnum > 400) & (wnum < 1900)]
wnum = wnum[(wnum > 400) & (wnum < 1900)]

with io.netcdf_file("out/tau_02.cdf", "r") as file_:
    wnum = file_.variables['wnum'][:].copy()
    radiance_cdf = file_.variables['radiance'][:].copy()
radiance[4] = radiance_cdf[(wnum > 400) & (wnum < 1900)]
wnum = wnum[(wnum > 400) & (wnum < 1900)]

with io.netcdf_file("out/tau_01.cdf", "r") as file_:
    wnum = file_.variables['wnum'][:].copy()
    radiance_cdf = file_.variables['radiance'][:].copy()
radiance[5] = radiance_cdf[(wnum > 400) & (wnum < 1900)]
wnum = wnum[(wnum > 400) & (wnum < 1900)]

with io.netcdf_file("out/tau_005.cdf", "r") as file_:
    wnum = file_.variables['wnum'][:].copy()
    radiance_cdf = file_.variables['radiance'][:].copy()
radiance[6] = radiance_cdf[(wnum > 400) & (wnum < 1900)]
wnum = wnum[(wnum > 400) & (wnum < 1900)]

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=300)
ax.plot(wnum, radiance[0], label=r"$\tau = 10$")
#plt.plot(wnum, radiance[1], ".", label=r"$\tau = 8$")
ax.plot(wnum, radiance[2], label=r"$\tau = 6$")
#plt.plot(wnum, radiance[3], ".", label=r"$\tau = 4$")
ax.plot(wnum, radiance[4], label=r"$\tau = 2$")
ax.plot(wnum, radiance[5], label=r"$\tau = 1$")
ax.plot(wnum, radiance[6], label=r"$\tau = 0.5$")
ax.legend(fontsize=16)
ax.grid(True)
ax.set_ylabel(r"Strahldichte ($\mathrm{mW \cdot (sr \cdot cm^{-1} \cdot m^2)^{-1}}$)", fontsize=16)
ax.set_xlabel(r"Wellenzahl ($\mathrm{cm^{-1}}$)", fontsize=16)
ax.tick_params(labelsize=12)
plt.savefig("/home/phi.richter/thermische_emission.png", bbox_inches="tight", dpi=300)
#plt.xlim([400, 1900])
#plt.ylim([0, 150])
