# %%
import scipy.io as io
import matplotlib.pyplot as plt

# %%
with io.netcdf_file("out/lbldisout.cdf", "r") as file_:
    print(file_.variables)
    wnum = file_.variables['wnum'][:].copy()
    radiance = file_.variables['radiance'][:].copy()
# Out:
# OrderedDict([('wnum', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0c550>), ('radiance', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0c8d0>), ('flux_up', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0cf50>), ('flux_down', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0c390>), ('flux_beam', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0cdd0>), ('cld_height', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0cb10>), ('cld_dbnum', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0c750>), ('cld_tau', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0ccd0>), ('cld_tau_wnum', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0ca10>), ('cld_reff', <scipy.io.netcdf.netcdf_variable object at 0x2af651cbd850>), ('sfc_temperature', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0f990>), ('sfc_emissivity', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0fd90>), ('pwv', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0fd10>), ('height', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0ff50>), ('pressure', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0f190>), ('temperature', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0f490>), ('mixing_ratio', <scipy.io.netcdf.netcdf_variable object at 0x2af651d0f610>)])

# %%
plt.plot(wnum, radiance)
