# %%
import scipy.io as io
import matplotlib.pyplot as plt

# %%
with io.netcdf_file("lbldisout.cdf", "r") as file_:
    print(file_.variables)
    wnum = file_.variables['wnum'][:].copy()
    radiance = file_.variables['radiance'][:].copy()
# Out:
# OrderedDict([('wnum', <scipy.io.netcdf.netcdf_variable object at 0x2af651b52510>), ('radiance', <scipy.io.netcdf.netcdf_variable object at 0x2af651b52750>), ('flux_up', <scipy.io.netcdf.netcdf_variable object at 0x2af651b52910>), ('flux_down', <scipy.io.netcdf.netcdf_variable object at 0x2af651b52a90>), ('flux_beam', <scipy.io.netcdf.netcdf_variable object at 0x2af651b52d10>), ('cld_height', <scipy.io.netcdf.netcdf_variable object at 0x2af651b52c10>), ('cld_dbnum', <scipy.io.netcdf.netcdf_variable object at 0x2af651b52e50>), ('cld_tau', <scipy.io.netcdf.netcdf_variable object at 0x2af651b54090>), ('cld_tau_wnum', <scipy.io.netcdf.netcdf_variable object at 0x2af651b54210>), ('cld_reff', <scipy.io.netcdf.netcdf_variable object at 0x2af651b54410>), ('sfc_temperature', <scipy.io.netcdf.netcdf_variable object at 0x2af651b54610>), ('sfc_emissivity', <scipy.io.netcdf.netcdf_variable object at 0x2af651b54a10>), ('pwv', <scipy.io.netcdf.netcdf_variable object at 0x2af651b549d0>), ('height', <scipy.io.netcdf.netcdf_variable object at 0x2af651b54b90>), ('pressure', <scipy.io.netcdf.netcdf_variable object at 0x2af651b54d50>), ('temperature', <scipy.io.netcdf.netcdf_variable object at 0x2af651b54f10>), ('mixing_ratio', <scipy.io.netcdf.netcdf_variable object at 0x2af651b59150>)])

# %%
plt.plot(wnum, radiance)
